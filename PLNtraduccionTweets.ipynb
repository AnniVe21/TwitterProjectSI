# %% [markdown]
# # Proyecto Sistemas de Información - Traducción Hugging face
#  Segundo semestre 2020
#
#  - Nayibe Yesenia Arias Cortez
#  - Anni
#  - Nathaly
#  - Jonathan

# %% [markdown]
# # [Huggingface Helsinki-NLP models](https://huggingface.co/Helsinki-NLP/opus-mt-es-en)

# %% [markdown]
# ![Captura de Pantalla 2022-02-09 a la(s) 11.02.19 p.m..png](data:image/png;base64,...)

# %%
pip install transformers -U

# %%
import transformers
from transformers import pipeline

# %%
pip install transformers[sentencepiece]

# %%
"""from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-es-en")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-es-en")"""
# Out:
# 'from transformers import AutoTokenizer, AutoModelForSeq2SeqLM\n\ntokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-es-en")\nmodel = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-es-en")'

# %%
"""inp = "esto es una prueba de traducción de español a inglés con huggingface Helsinki-NLP models"
input_ids = tokenizer(inp, return_tensors="pt").input_ids
outputs = model.generate(input_ids=input_ids, num_beams=5, num_return_sequences=3)
print("Generated:", tokenizer.batch_decode(outputs, skip_special_tokens=True))
"""
# Out:
# 'inp = "esto es una prueba de traducción de español a inglés con huggingface Helsinki-NLP models"\ninput_ids = tokenizer(inp, return_tensors="pt").input_ids\noutputs = model.generate(input_ids=input_ids, num_beams=5, num_return_sequences=3)\nprint("Generated:", tokenizer.batch_decode(outputs, skip_special_tokens=True))\n'

# %%
text="hola"
# Iniciar Traductor
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-es-en")
# Traducir texto
traduccion = translator(text)
# Mostrar Traducción
traduccion
# Out:
# Downloading:   0%|          | 0.00/807k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/783k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52M [00:00<?, ?B/s]
# [{'translation_text': 'Hello.'}]
