# %% [markdown]
# # Proyecto Sistemas de Información - Análisis de sentimiento Hugging face
#  Segundo semestre 2020
#
#  - Nayibe Yesenia Arias Cortez
#  - Anni
#  - Nathaly
#  - Jonathan

# %% [markdown]
# # [beto-sentiment-analysis](https://huggingface.co/finiteautomata/beto-sentiment-analysis)

# %% [markdown]
# ![Captura de Pantalla 2022-02-10 a la(s) 12.24.34 a.m..png](data:image/png;base64,...)

# %%
pip install transformers -U
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 9.1 MB/s
# ...
#      |████████████████████████████████| 67 kB 3.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 44.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 47.6 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 12.7 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import transformers
from transformers import pipeline

# %%
sentimiento = pipeline("sentiment-analysis",model="finiteautomata/beto-sentiment-analysis")
# Out:
# Downloading:   0%|          | 0.00/841 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/528 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/236k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/469k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# ## Ejemplo:

# %%
sentimiento('no está nada mal la pizza ')
# Out:
# [{'label': 'POS', 'score': 0.9981861710548401}]
